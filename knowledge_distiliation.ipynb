# %%
try:
  from torchsummary import summary
except:
  # !pip install torchsummary
  from torchsummary import summary

try:
  from torchmetrics import Accuracy
except:
  # !pip install torchmetrics
  from torchmetrics import Accuracy

from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader

#new 
from torchvision import models
from torchvision import transforms
from torchsummary import summary

try:
  import fiftyone as fo
except:
  # !pip install fiftyone
  import fiftyone as fo
import fiftyone.zoo as foz
from fiftyone import ViewField as F
import fiftyone.utils.coco as fouc
from torchvision.transforms import functional as func
import fiftyone.brain as fob
import eta.core.utils as etau
import fiftyone.utils.random as four
import torch

try:
  from ultralytics import YOLO
except:
  # !pip install ultralytics
  from ultralytics import YOLO
import requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 10.0 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 74.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 13.6 MB/s eta 0:00:00
# ...

# %%
'''
download the helper functions
'''
helper_file = "helper_funs.py"
field_file = "field_names.py"

helper_functions = requests.get("https://raw.githubusercontent.com/NoumanAhmad448/deep_learning_pytorch_python_computer_vision/master/helper_funs.py")
with open(helper_file, "wb") as module:
  module.write(helper_functions.content)

from helper_funs import *
# ******************************************
helper_functions = requests.get("https://raw.githubusercontent.com/NoumanAhmad448/deep_learning_pytorch_python_computer_vision/master/field_names.py")
with open(field_file, "wb") as module:
  module.write(helper_functions.content)

from field_names import *

# %%
mount_google_drive()
# Out:
# Mounted at /content/gdrive/

# %%
project = "/content/gdrive/MyDrive/paper02"
project = "/content/gdrive/MyDrive/data/coco-17/output_17_1"

# %%
# !wget https://fastly.picsum.photos/id/237/536/354.jpg?hmac=i0yVXW1ORpyCZpQ-CknuyV-jbtU7_x9EBQVhvT5aRr0 -O test.jpg
# Out:
# --2023-06-07 02:50:26--  https://fastly.picsum.photos/id/237/536/354.jpg?hmac=i0yVXW1ORpyCZpQ-CknuyV-jbtU7_x9EBQVhvT5aRr0
# Resolving fastly.picsum.photos (fastly.picsum.photos)... 151.101.1.91, 151.101.65.91, 151.101.129.91, ...
# Connecting to fastly.picsum.photos (fastly.picsum.photos)|151.101.1.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35581 (35K) [image/jpeg]
# Saving to: ‘test.jpg’
#
# test.jpg            100%[===================>]  34.75K  --.-KB/s    in 0.002s
#
# 2023-06-07 02:50:26 (15.1 MB/s) - ‘test.jpg’ saved [35581/35581]

# %%
project
# Out:
# '/content/gdrive/MyDrive/data/coco-17/coco_17_1'

# %%
inputs = ["test.jpg"]  # list of numpy arrays
# model = YOLO(project+"/results/weights/best.pt")
model = YOLO(project+"/model_final.pt")
results = model(inputs)  # list of Results objects

# for result in results:
#     boxes = result.boxes  # Boxes object for bbox outputs
#     masks = result.masks  # Masks object for segmentation masks outputs
#     probs = result.probs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1d6c5c0da37a> in <cell line: 3>()
#       1 inputs = ["test.jpg"]  # list of numpy arrays
#       2 # model = YOLO(project+"/results/weights/best.pt")
# ----> 3 model = YOLO(project+"/model_final.pt")
#       4 results = model(inputs)  # list of Results objects
#       5
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in __init__(self, model, task)
#     105             self._new(model, task)
#     106         else:
# --> 107             self._load(model, task)
#     108
#     109     def __call__(self, source=None, stream=False, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in _load(self, weights, task)
#     154         suffix = Path(weights).suffix
#     155         if suffix == '.pt':
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
annotated_frame = results[0].plot()

cv2_imshow(annotated_frame)

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Dataset '/usr/local/lib/python3.10/dist-packages/ultralytics/datasets/coco128.yaml' images not found ⚠️, missing paths ['/content/datasets/coco128/images/train2017']
# ...
# 100%|██████████| 6.66M/6.66M [00:00<00:00, 60.5MB/s]
# Unzipping /content/datasets/coco128.zip to /content/datasets...
# Dataset download success ✅ (0.8s), saved to /content/datasets
#
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 29.9MB/s]
# val: Scanning /content/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<00:00, 1792.15it/s]
# val: New cache created: /content/datasets/coco128/labels/train2017.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:09<00:00,  1.23s/it]
#                    all        128        929       0.95      0.871      0.933      0.806
# ...

# %%
cm = model.val().confusion_matrix

# %%
cm.plot()

# %%
results = model.predict(inputs)
type(results)
# Out:
# 0: 448x640 1 dog, 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# list

# %%
results
# Out:
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

model.train(data='coco128.yaml', epochs=100, imgsz=640,batch=32,save=True,
            project=project, name="results")
# Out:
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# ...
